# %%
# First, define the html variable with your content
html = """<!DOCTYPE html>
<html>
<head>
    <title>Netflix Dashboard</title>
</head>
<body>
    <h1>Netflix Dashboard</h1>
    <!-- Your dashboard content here -->
</body>
</html>"""

# Now write it to the file
with open("netflix_dashboard.html", "w", encoding="utf-8") as f:
    f.write(html)
print("Saved!")
# Out:
# Saved!
